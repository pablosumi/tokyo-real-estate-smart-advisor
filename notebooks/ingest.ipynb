# %%
import pandas as pd
import requests
import json
from datetime import date

# %% [markdown]
# # Ministry of Land, Infrastructure, Transport and Tourism (MLIT)
# ### Real estate price (transaction price/contract price) information acquisition
#
# https://www.reinfolib.mlit.go.jp/help/apiManual/#titleApi4

# %%
# configurations

with open('../env.json', 'r') as config_file:
    api_key = json.load(config_file).get('MLIT_API_KEY')

base_url = "https://www.reinfolib.mlit.go.jp/ex-api/external/XIT001"
headers = {"Ocp-Apim-Subscription-Key": api_key}

pref_code = "13"  # Tokyo Prefecture
from_date = 2010
to_date = date.today().year + 1

# %%
# data fetch and aggregation

all_transactions = []

for year in range(from_date, to_date):

    params = {
        "area": pref_code,
        "year": year,
        "language":"en"
    }

    response = requests.get(base_url, headers=headers, params=params)
    all_transactions.extend(response.json()["data"])

df = pd.DataFrame(all_transactions)
df.head()
# Out:
#                                PriceCategory  \
# 0  Real Estate Transaction Price Information
# 1  Real Estate Transaction Price Information
# 2  Real Estate Transaction Price Information
# 3  Real Estate Transaction Price Information
# 4  Real Estate Transaction Price Information
#
#                                   Type           Region MunicipalityCode  \
# 0  Residential Land(Land and Building)  Commercial Area            13101
# 1         Pre-owned Condominiums, etc.                             13101
# 2         Pre-owned Condominiums, etc.                             13101
# 3         Pre-owned Condominiums, etc.                             13101
# 4         Pre-owned Condominiums, etc.                             13101
#
#   Prefecture  Municipality  DistrictName TradePrice PricePerUnit FloorPlan  \
# 0      Tokyo  Chiyoda Ward  Higashikanda   14000000
# 1      Tokyo  Chiyoda Ward  Higashikanda    7300000                     1K
# 2      Tokyo  Chiyoda Ward  Higashikanda    8200000                     1K
# 3      Tokyo  Chiyoda Ward  Higashikanda   10000000
# 4      Tokyo  Chiyoda Ward    Iwamotocho   11000000                     1R
#
#    ... Direction Classification Breadth     CityPlanning CoverageRatio  \
# 0  ...      East   Private Road       3  Commercial Zone            80
# 1  ...                                   Commercial Zone            80
# 2  ...                                   Commercial Zone            80
# 3  ...                                   Commercial Zone            80
# 4  ...                                   Commercial Zone            80
#
#   FloorAreaRatio            Period Renovation  \
# 0            500  2nd quarter 2010
# 1            600  2nd quarter 2010    Not yet
# 2            700  2nd quarter 2010    Not yet
# 3            500  2nd quarter 2010
# 4            700  2nd quarter 2010    Not yet
#
#                            Remarks DistrictCode
# 0  Dealings including private road    131010500
# 1                                     131010500
# 2                                     131010500
# 3                                     131010500
# 4                                     131010030
#
# [5 rows x 29 columns]

# %%
# data write

df.to_excel('../data/tokyo.xlsx', index=False)
