# %%
import pandas as pd
import requests
import os
from datetime import date
from dotenv import load_dotenv

# %% [markdown]
# # Ministry of Land, Infrastructure, Transport and Tourism (MLIT)
# ### Real estate price (transaction price/contract price) information acquisition
#
# https://www.reinfolib.mlit.go.jp/help/apiManual/#titleApi4

# %%
# load environment variables and access MLIT api key
load_dotenv()
api_key = os.getenv("MLIT_API_KEY")

if not api_key:
    raise ValueError("API Key not found. Please check your .env file.")

print("API Key loaded successfully.")

base_url = "https://www.reinfolib.mlit.go.jp/ex-api/external/XIT001"
headers = {"Ocp-Apim-Subscription-Key": api_key}

pref_code = "13"  # Tokyo Prefecture
from_date = 2010
to_date = date.today().year + 1
# Out:
# API Key loaded successfully.

# %%
# data fetch and aggregation

all_transactions = []

for year in range(from_date, to_date):

    params = {
        "area": pref_code,
        "year": year,
        "language":"en"
    }

    response = requests.get(base_url, headers=headers, params=params)
    all_transactions.extend(response.json()["data"])

df = pd.DataFrame(all_transactions)
df.head()
# Out:
#                                PriceCategory                          Type  \
# 0  Real Estate Transaction Price Information  Pre-owned Condominiums, etc.
# 1  Real Estate Transaction Price Information  Pre-owned Condominiums, etc.
# 2  Real Estate Transaction Price Information  Pre-owned Condominiums, etc.
# 3  Real Estate Transaction Price Information  Pre-owned Condominiums, etc.
# 4  Real Estate Transaction Price Information  Pre-owned Condominiums, etc.
#
#   Region MunicipalityCode Prefecture  Municipality DistrictName TradePrice  \
# 0                   13101      Tokyo  Chiyoda Ward    Iidabashi   47000000
# 1                   13101      Tokyo  Chiyoda Ward    Iidabashi   21000000
# 2                   13101      Tokyo  Chiyoda Ward   Ichibancho   63000000
# 3                   13101      Tokyo  Chiyoda Ward   Ichibancho   35000000
# 4                   13101      Tokyo  Chiyoda Ward   Ichibancho  170000000
#
#   PricePerUnit FloorPlan  ... Direction Classification Breadth  \
# 0                    3DK  ...
# 1                    1DK  ...
# 2                   1LDK  ...
# 3                   2LDK  ...
# 4                   3LDK  ...
#
#                    CityPlanning CoverageRatio FloorAreaRatio  \
# 0               Commercial Zone            80            600
# 1               Commercial Zone            80            700
# 2               Commercial Zone            80            500
# 3  Category II Residential Zone            60            400
# 4  Category II Residential Zone            80            500
#
#              Period Renovation Remarks DistrictCode
# 0  2nd quarter 2010       Done            131010010
# 1  2nd quarter 2010       Done            131010010
# 2  2nd quarter 2010    Not yet            131010020
# 3  2nd quarter 2010    Not yet            131010020
# 4  2nd quarter 2010    Not yet            131010020
#
# [5 rows x 29 columns]

# %%
# data write to parquet

try:
    df.to_parquet('../data/tokyo.parquet', index=False)
    print(f"successfuly wrote {df.shape[0]} rows and {df.shape[1]} columns to parquet file: ../data/tokyo.parquet")
except Exception as e:
    print(f"error writing to parquet: {e}")
# Out:
# successfuly wrote 607756 rows and 29 columns to parquet file: ../data/tokyo.parquet
